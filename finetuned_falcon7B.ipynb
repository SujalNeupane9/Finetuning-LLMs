# %%
# !pip install -q -U trl transformers accelerate git+https://github.com/huggingface/peft.git
# !pip install -q datasets bitsandbytes einops wandb
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done

# %%
import torch
from datasets import load_dataset
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
from peft import LoraConfig
from transformers import TrainingArguments
from trl import SFTTrainer

dataset = load_dataset("timdettmers/openassistant-guanaco",split='train')
dataset
# Out:
# WARNING:datasets.builder:Found cached dataset json (/root/.cache/huggingface/datasets/timdettmers___json/timdettmers--openassistant-guanaco-6126c710748182cf/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96)
# Dataset({
#     features: ['text'],
#     num_rows: 9846
# })

# %%
model_name = "ybelkada/falcon-7b-sharded-bf16"

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    trust_remote_code=True
)
model.config.use_cache = False
# Out:
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]

# %%
tokenizer=AutoTokenizer.from_pretrained(
    model_name,trust_remote_code=True
)
tokenizer.pad_token = tokenizer.eos_token
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/180 [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/2.73M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/281 [00:00<?, ?B/s]

# %%
lora_alpha = 16
lora_dropout = 0.1
lora_r = 64

peft_config = LoraConfig(
    lora_alpha=lora_alpha,
    lora_dropout=lora_dropout,
    r = lora_r,
    bias='none',
    task_type="CAUSAL_LM",
    target_modules=[
        "query_key_value",
        "dense",
        "dense_h_to_4h",
        "dense_4h_to_h"
    ]
)

# %%
training_arguments = TrainingArguments(
    output_dir="./results",
    per_device_train_batch_size=4,
    gradient_accumulation_steps=4,
    optim='paged_adamw_32bit',
    save_steps=10,
    logging_steps=10,
    learning_rate=2e-4,
    fp16=True,
    max_grad_norm=0.3,
    max_steps=500,
    warmup_ratio=0.03,
    lr_scheduler_type="constant"
)

trainer=SFTTrainer(
    model=model,
    train_dataset=dataset,
    peft_config=peft_config,
    dataset_text_field="text",
    max_seq_length=512,
    tokenizer=tokenizer,
    args=training_arguments
)
# Out:
# /usr/local/lib/python3.10/dist-packages/peft/utils/other.py:102: FutureWarning: prepare_model_for_int8_training is deprecated and will be removed in a future version. Use prepare_model_for_kbit_training instead.
#   warnings.warn(
# Map:   0%|          | 0/9846 [00:00<?, ? examples/s]

# %%
for name, module in trainer.model.named_modules():
    if "norm" in name:
        module = module.to(torch.float32)

# %%
trainer.train()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.15.5
# Run data is saved locally in <code>/content/wandb/run-20230719_083056-44nbgijx</code>
# Syncing run <strong><a href='https://wandb.ai/neupane9sujal/huggingface/runs/44nbgijx' target="_blank">radiant-resonance-2</a></strong> to <a href='https://wandb.ai/neupane9sujal/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/neupane9sujal/huggingface' target="_blank">https://wandb.ai/neupane9sujal/huggingface</a>
#  View run at <a href='https://wandb.ai/neupane9sujal/huggingface/runs/44nbgijx' target="_blank">https://wandb.ai/neupane9sujal/huggingface/runs/44nbgijx</a>
# You're using a PreTrainedTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='98' max='500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 98/500 40:36 < 2:50:02, 0.04 it/s, Epoch 0.16/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>1.519500</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.353800</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.312900</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.404900</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.283900</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.307000</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>1.355900</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>1.405800</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>1.302300</td>
#     </tr>
#   </tbody>
# </table><p>
